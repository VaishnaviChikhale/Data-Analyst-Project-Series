# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import seaborn as sns

# %%
df=pd.read_csv('WeatherData.csv')

# %%
df
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0     2012-01-01 00:00:00    -1.8              -3.9       86.0
# 1     2012-01-01 01:00:00    -1.8              -3.7       87.0
# 2     2012-01-01 02:00:00    -1.8              -3.4       89.0
# 3     2012-01-01 03:00:00    -1.5              -3.2       88.0
# 4     2012-01-01 04:00:00    -1.5              -3.3       88.0
# ...                   ...     ...               ...        ...
# 8779  2012-12-31 19:00:00     0.1              -2.7       81.0
# 8780  2012-12-31 20:00:00     0.2              -2.4       83.0
# 8781  2012-12-31 21:00:00    -0.5              -1.5       93.0
# 8782  2012-12-31 22:00:00    -0.2              -1.8       89.0
# 8783  2012-12-31 23:00:00     0.0              -2.1       86.0
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# **Insights:**
#
# * The "WeatherData.csv" file contains a series of weather data entries spanning from December 19th, 2012 to December 27th, 2012.
# * It includes details such as temperature, humidity, wind speed, and weather conditions for each hour during this period.
# * The data covers a range of weather conditions including cloudy, drizzle, snow, rain, and fog.
# * The information is organized in chronological order and provides a comprehensive overview of the weather patterns during this time frame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   float64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 549.1+ KB

# %%
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# **Insight:**
#
# * No. of rows or entries= 8783
#
# * No. of columns or features= 8

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# **Insights:**
#
# * There are no null values in the dataset.

# %%
weather=df['Weather'].value_counts()
dfweather=pd.DataFrame(weather)
dfweather = dfweather.reset_index()
dfweather.columns = ['Weather', 'Frequency']
dfweather
# Out:
#                                     Weather  Frequency
# 0                              Mainly Clear       2106
# 1                             Mostly Cloudy       2069
# 2                                    Cloudy       1728
# 3                                     Clear       1326
# 4                                      Snow        390
# 5                                      Rain        306
# 6                              Rain Showers        188
# 7                                       Fog        150
# 8                                  Rain,Fog        116
# 9                               Drizzle,Fog         80
# 10                             Snow Showers         60
# 11                                  Drizzle         41
# 12                                 Snow,Fog         37
# 13                        Snow,Blowing Snow         19
# 14                                Rain,Snow         18
# 15               Thunderstorms,Rain Showers         16
# ...

# %% [markdown]
# To find unique instances of weather types.
#
# **Insights:**
#
# * The weature observed most is "Mainly Clear".
# * The 4 most likely weature conditions (and their frequency) are:
#   1.   Mainly Clear	(2106)
#   2.   Mostly Cloudy	(2069)
#   3.   Cloudy	(1728)
#   4. 	 Clear	(1326)
#   5.   Snow	(390)

# %%
df[df['Weather'] == 'Clear']
# Out:
#                 Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67    2012-01-03 19:00:00   -16.9             -24.8       50.0
# 114   2012-01-05 18:00:00    -7.1             -14.4       56.0
# 115   2012-01-05 19:00:00    -9.2             -15.4       61.0
# 116   2012-01-05 20:00:00    -9.8             -15.7       62.0
# 117   2012-01-05 21:00:00    -9.0             -14.8       63.0
# ...                   ...     ...               ...        ...
# 8646  2012-12-26 06:00:00   -13.4             -14.8       89.0
# 8698  2012-12-28 10:00:00    -6.1              -8.6       82.0
# 8713  2012-12-29 01:00:00   -11.9             -13.6       87.0
# 8714  2012-12-29 02:00:00   -11.8             -13.1       90.0
# 8756  2012-12-30 20:00:00   -13.8             -16.5       80.0
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %%
mean1=df['Temp_C'].mean()
print("Temp_C: ",mean1)

mean2=df['Wind Speed_km/h'].mean()
print("Wind Speed_km/h: ",mean2)

mean3=df['Visibility_km'].mean()
print("Visibility_km: ",mean3)
# Out:
# Temp_C:  8.798144353369764
# Wind Speed_km/h:  14.94546903460838
# Visibility_km:  27.664446721311478

# %% [markdown]
# **Insights:**
#
# * The average temperature is approximately 8.8°C.
# * The average wind speed is about 14.95 km/h.
# * The average visibility is around 27.66 km.

# %%
var1=df['Press_kPa'].var()
print("Press_kPa: ",var1)
# Out:
# Press_kPa:  0.7123440111838423

# %% [markdown]
# **Insight:**
#
# * The variance of Press_kPa is 0.7123, indicating moderate variability in atmospheric pressure within the dataset.

# %%
windspeed=df[(df['Wind Speed_km/h'] <=30) & (df['Temp_C']>0)]
print(windspeed['Date/Time'])
print(windspeed.shape)
# Out:
# 13      2012-01-01 13:00:00
# 14      2012-01-01 14:00:00
# 15      2012-01-01 15:00:00
# 16      2012-01-01 16:00:00
# 17      2012-01-01 17:00:00
#                ...
# 8545    2012-12-22 01:00:00
# 8546    2012-12-22 02:00:00
# 8547    2012-12-22 03:00:00
# 8779    2012-12-31 19:00:00
# 8780    2012-12-31 20:00:00
# Name: Date/Time, Length: 6302, dtype: object
# (6302, 8)

# %%
snow=df[df['Weather'] == 'Snow']
snow.loc[:, ['Date/Time', 'Temp_C']]
# Out:
#                 Date/Time  Temp_C
# 55    2012-01-03 07:00:00   -14.0
# 84    2012-01-04 12:00:00   -13.7
# 86    2012-01-04 14:00:00   -11.3
# 87    2012-01-04 15:00:00   -10.2
# 88    2012-01-04 16:00:00    -9.4
# ...                   ...     ...
# 8779  2012-12-31 19:00:00     0.1
# 8780  2012-12-31 20:00:00     0.2
# 8781  2012-12-31 21:00:00    -0.5
# 8782  2012-12-31 22:00:00    -0.2
# 8783  2012-12-31 23:00:00     0.0
#
# [390 rows x 2 columns]

# %%
graph=df[['Temp_C', 'Date/Time']]
graph.plot(x='Date/Time', y='Temp_C',figsize=(10,7) )
# Out:
# <Axes: xlabel='Date/Time'>

# %%
keep=dfweather[dfweather['Frequency']>20]
print(keep)
keep.plot.pie(y='Frequency',autopct='%1.1f%%', shadow=False, figsize=(12,9))
plt.title("Weather Conditions")
plt.show()
# Out:
#           Weather  Frequency
# 0    Mainly Clear       2106
# 1   Mostly Cloudy       2069
# 2          Cloudy       1728
# 3           Clear       1326
# 4            Snow        390
# 5            Rain        306
# 6    Rain Showers        188
# 7             Fog        150
# 8        Rain,Fog        116
# 9     Drizzle,Fog         80
# 10   Snow Showers         60
# 11        Drizzle         41
# 12       Snow,Fog         37

# %% [markdown]
# **Correlation**

# %%
numeric_df = df.select_dtypes(include=[float, int])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
fig, ax = plt.subplots(figsize=(5,4))
sns.heatmap(correlation_matrix , annot=True, ax=ax, cmap = 'mako')
# Out:
# <Axes: >

# %% [markdown]
# **Insight:**
#
# Strong correlation between Temperature and Dew Point.

# %% [markdown]
# **Regression Analysis:**

# %%
features = ['Rel Hum_%', 'Dew Point Temp_C', 'Wind Speed_km/h', 'Visibility_km', 'Press_kPa']
X = df.loc[:, features]
y = df.loc[:, 'Temp_C']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 0.7143056054037357
# R-squared: 0.9950225814501568

# %%
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
print(coefficients)
# Out:
#                   Coefficient
# Rel Hum_%           -0.248757
# Dew Point Temp_C     1.052389
# Wind Speed_km/h     -0.004525
# Visibility_km       -0.003451
# Press_kPa           -0.076643

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Temperature')
plt.ylabel('Predicted Temperature')
plt.title('Actual vs Predicted Temperature')
plt.show()

# %% [markdown]
# **Insight:**
#
# * Linear regression used to predict temperature based on selected features.

# %%
residuals = y_test - y_pred
sns.histplot(residuals, kde=True)
plt.title('Residuals Distribution')
plt.show()

# %% [markdown]
# **Insights:**
#
#  Analyzed to assess model performance.
